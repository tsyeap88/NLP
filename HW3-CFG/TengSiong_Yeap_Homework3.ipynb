# %%
import nltk

# %%
# read the sentences from the file sentences.txt
sentfile = open('sentences.txt', 'r')
# make a list of sentences, separating the tokens by white space.
sentence_list = []
for line in sentfile:
    sentence_list.append(line.split())

# %%
# read the grammar file - the nltk data function load will not reload
#    the file unless you set the cache to be False
camg = nltk.data.load('file:camelot_grammar.cfg', cache=False)

# %%
# create a recursive descent parser
cam_parser = nltk.RecursiveDescentParser(camg)

# %%
# for each sentence print it and its parse trees
# if the grammar cannot parse a sentence, sometimes it gives an error and
#    sometimes it just goes on to the next sentence with no parse tree
for sent in sentence_list:
    print(sent)
    for tree in cam_parser.parse(sent):
        print (tree)
# Out:
# ['Arthur', 'is', 'the', 'king', '.']
# (START
#   (S1
#     (NP (Proper Arthur))
#     (VP (VerbT is) (NP (Det the) (NP (Noun king))))
#     (Eos .)))
# ['Arthur', 'rides', 'the', 'horse', 'near', 'the', 'castle', '.']
# (START
#   (S1
#     (NP (Proper Arthur))
#     (VP
#       (VerbT rides)
#       (NP
#         (Det the)
#         (NP
#           (Noun horse)
#           (PP (Prep near) (NP (Det the) (NP (Noun castle)))))))
#     (Eos .)))
# (START
#   (S1
#     (NP (Proper Arthur))
#     (VP
#       (VerbT rides)
#       (NP (Det the) (NP (Noun horse)))
#       (PP (Prep near) (NP (Det the) (NP (Noun castle)))))
#     (Eos .)))
# (START
#   (S1
#     (NP (Proper Arthur))
#     (VP (VerbT rides) (NP (Det the) (NP (Noun horse))))
#     (PP (Prep near) (NP (Det the) (NP (Noun castle))))
#     (Eos .)))
# ['Arthur', 'rides', 'the', 'plodding', 'horse', 'near', 'the', 'castle', '.']
# (START
#   (S1
#     (NP (Proper Arthur))
#     (VP
#       (VerbT rides)
#       (NP
#         (Det the)
#         (NP
#           (Adj plodding)
#           (NP
#             (Noun horse)
#             (PP (Prep near) (NP (Det the) (NP (Noun castle))))))))
#     (Eos .)))
# (START
#   (S1
#     (NP (Proper Arthur))
#     (VP
#       (VerbT rides)
#       (NP (Det the) (NP (Adj plodding) (NP (Noun horse))))
#       (PP (Prep near) (NP (Det the) (NP (Noun castle)))))
#     (Eos .)))
# (START
#   (S1
#     (NP (Proper Arthur))
#     (VP
#       (VerbT rides)
#       (NP (Det the) (NP (Adj plodding) (NP (Noun horse)))))
#     (PP (Prep near) (NP (Det the) (NP (Noun castle))))
#     (Eos .)))
# ['the', 'Holy_Grail', 'is', 'a', 'chalice', '.']
# (START
#   (S1
#     (NP (Det the) (NP (NPN Holy_Grail)))
#     (VP (VerbT is) (NP (Det a) (NP (Noun chalice))))
#     (Eos .)))
# ['the', 'sensational', 'Holy_Grail', 'is', 'a', 'sacred', 'chalice', '.']
# (START
#   (S1
#     (NP (Det the) (NP (Adj sensational) (NP (NPN Holy_Grail))))
#     (VP
#       (VerbT is)
#       (NP (Det a) (NP (Adj sacred) (NP (Noun chalice)))))
#     (Eos .)))
# ['every', 'coconut', 'was', 'carried', 'to', 'the', 'hottest', 'mountains', '.']
# (START
#   (S1
#     (NP (Det every) (NP (Noun coconut)))
#     (VP
#       (VpastT was)
#       (VP
#         (VpastP carried)
#         (PP
#           (TOwork
#             (TO to)
#             (NP
#               (Det the)
#               (NP (SuperAdj hottest) (NP (Nplural mountains))))))))
#     (Eos .)))
# (START
#   (S1
#     (NP (Det every) (NP (Noun coconut)))
#     (VP
#       (VpastT was)
#       (VP
#         (VpastT carried)
#         (PP
#           (TOwork
#             (TO to)
#             (NP
#               (Det the)
#               (NP (SuperAdj hottest) (NP (Nplural mountains))))))))
#     (Eos .)))
# (START
#   (S1
#     (NP (Det every) (NP (Noun coconut)))
#     (VP (VpastT was) (VP (VpastP carried)))
#     (PP
#       (TOwork
#         (TO to)
#         (NP
#           (Det the)
#           (NP (SuperAdj hottest) (NP (Nplural mountains))))))
#     (Eos .)))
# ['sixty', 'strangers', 'are', 'at', 'the', 'Round_Table', '.']
# (START
#   (S1
#     (NP (NUM sixty) (NP (Nplural strangers)))
#     (VP
#       (VPPT are)
#       (PP (Prep at) (NP (Det the) (NP (NPN Round_Table)))))
#     (Eos .)))
# ['Sir_Lancelot', 'might', 'have', 'spoken', '.']
# (START
#   (S1
#     (NP (Proper Sir_Lancelot))
#     (VP (aux might) (VP (Vbase have) (VP (VpastP spoken))))
#     (Eos .)))
# ['Guinevere', 'had', 'been', 'riding', 'with', 'Patsy', 'for', 'five', 'weary', 'nights', '.']
# (START
#   (S1
#     (NP (Proper Guinevere))
#     (VP
#       (VpastT had)
#       (VP
#         (VpastP been)
#         (VP
#           (V-ing riding)
#           (PP
#             (Prep with)
#             (NP
#               (Proper Patsy)
#               (PP
#                 (Prep for)
#                 (NP
#                   (NUM five)
#                   (NP (Adj weary) (NP (Nplural nights))))))))))
#     (Eos .)))
# (START
#   (S1
#     (NP (Proper Guinevere))
#     (VP
#       (VpastP had)
#       (VP
#         (VpastP been)
#         (VP
#           (V-ing riding)
#           (PP
#             (Prep with)
#             (NP
#               (Proper Patsy)
#               (PP
#                 (Prep for)
#                 (NP
#                   (NUM five)
#                   (NP (Adj weary) (NP (Nplural nights))))))))))
#     (Eos .)))
# (START
#   (S1
#     (NP (Proper Guinevere))
#     (VP
#       (VpastT had)
#       (VP
#         (VpastP been)
#         (VP (V-ing riding) (PP (Prep with) (NP (Proper Patsy))))))
#     (PP
#       (Prep for)
#       (NP (NUM five) (NP (Adj weary) (NP (Nplural nights)))))
#     (Eos .)))
# (START
#   (S1
#     (NP (Proper Guinevere))
#     (VP
#       (VpastP had)
#       (VP
#         (VpastP been)
#         (VP (V-ing riding) (PP (Prep with) (NP (Proper Patsy))))))
#     (PP
#       (Prep for)
#       (NP (NUM five) (NP (Adj weary) (NP (Nplural nights)))))
#     (Eos .)))
# ['Sir_Bedevere', 'might', 'have', 'been', 'suggesting', 'this', 'quest', '.']
# (START
#   (S1
#     (NP (Proper Sir_Bedevere))
#     (VP
#       (aux might)
#       (VP
#         (Vbase have)
#         (VP
#           (VpastP been)
#           (VP (V-ing suggesting) (NP (Det this) (NP (Noun quest)))))))
#     (Eos .)))
# ['the', 'Britons', 'migrate', 'south', 'frequently', '.']
# (START
#   (S1
#     (NP (Det the) (NP (properS Britons)))
#     (VP (VPPT migrate) (Adv south) (Adv frequently))
#     (Eos .)))
# ['Arthur', 'and', 'Guinevere', 'ride', 'frequently', 'near', 'the', 'castle', '.']
# (START
#   (S1
#     (NP (Proper Arthur) (Conj and) (Proper Guinevere))
#     (VP
#       (VPPT ride)
#       (Adv frequently)
#       (PP (Prep near) (NP (Det the) (NP (Noun castle)))))
#     (Eos .)))
# ['he', 'suggests', 'to', 'grow', 'fruit', 'at', 'home', '.']
# (START
#   (S1
#     (NP (pronoun he))
#     (VP
#       (Vsingular suggests)
#       (TOwork
#         (TO to)
#         (VP
#           (Vbase grow)
#           (NP (Noun fruit))
#           (PP (Prep at) (NP (Noun home))))))
#     (Eos .)))
# (START
#   (S1
#     (NP (pronoun he))
#     (VP
#       (Vsingular suggests)
#       (TOwork
#         (TO to)
#         (VP
#           (Vbase grow)
#           (NP (Noun fruit) (PP (Prep at) (NP (Noun home)))))))
#     (Eos .)))
# (START
#   (S1
#     (NP (pronoun he))
#     (VP
#       (Vsingular suggests)
#       (TOwork (TO to) (VP (Vbase grow) (NP (Noun fruit)))))
#     (PP (Prep at) (NP (Noun home)))
#     (Eos .)))
# ['riding', 'to', 'Camelot', 'is', 'not', 'hard', '.']
# (START
#   (S1
#     (NP (V-ing riding) (PP (TOwork (TO to) (NP (NPN Camelot)))))
#     (VP (VerbT is) (NOTwork (NOT not) (Adj hard)))
#     (Eos .)))
# ['do', 'coconuts', 'speak', '?']
# (START
#   (S1
#     (DO do)
#     (S1 (NP (Nplural coconuts)) (VP (Vbase speak)) (Eos ?))))
# ['why', 'does', 'England', 'have', 'a', 'king', '?']
# (START
#   (S1
#     (WHadv why)
#     (S1
#       (DO does)
#       (S1
#         (NP (NPN England))
#         (VP (Vbase have) (NP (Det a) (NP (Noun king))))
#         (Eos ?)))))
# ['unfortunately', ',', 'Sir_Lancelot', 'speaks', 'again', '.']
# (START
#   (S1
#     (Adv unfortunately)
#     (pause ,)
#     (S1
#       (NP (Proper Sir_Lancelot))
#       (VP (Vsingular speaks) (Adv again))
#       (Eos .))))
# ['who', 'does', 'Arthur', 'suggest', 'she', 'carry', '?']
# (START
#   (S1
#     (WHpronoun who)
#     (S1
#       (DO does)
#       (S1
#         (NP (Proper Arthur))
#         (VP
#           (Vbase suggest)
#           (S (NP (pronoun she)) (VP (Vbase carry))))
#         (Eos ?)))))
# ['Arthur', 'rode', 'to', 'Camelot', 'and', 'drank', 'from', 'his', 'chalice', '.']
# (START
#   (S1
#     (NP (Proper Arthur))
#     (VP (VpastT rode) (PP (TOwork (TO to) (NP (NPN Camelot)))))
#     (Conj and)
#     (VP
#       (VpastT drank)
#       (PP (Prep from) (NP (PPP his) (NP (Noun chalice)))))
#     (Eos .)))
# ['having', 'to', 'had', 'have', 'had', '.']
# (START
#   (S1
#     (NP
#       (V-ing having)
#       (PP (TOwork (TO to) (VP (VpastT had) (VP (Vbase have))))))
#     (VP (VpastP had))
#     (Eos .)))
# (START
#   (S1
#     (NP (V-ing having) (PP (TOwork (TO to) (VP (VpastP had)))))
#     (VP (Vbase have) (VP (VpastP had)))
#     (Eos .)))
# (START
#   (S1
#     (NP
#       (V-ing having)
#       (PP (TOwork (TO to) (VP (VpastP had) (VP (Vbase have))))))
#     (VP (VpastP had))
#     (Eos .)))
# ['to', 'the', 'south', ',', 'he', 'is', 'riding', 'his', 'horse', '.']
